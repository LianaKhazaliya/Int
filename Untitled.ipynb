# %%
import csv
import numpy
import pandas as pd
from sklearn.decomposition import PCA
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns
from bs4 import BeautifulSoup
import requests
import re
import os, sys
from mpl_toolkits.mplot3d import Axes3D

def get_data_about_smb(input_file, names, *parameters):
    data = []
    for name in names:
        with open(input_file, mode = 'r') as csvfile:
            reader = csv.DictReader(csvfile) 
            for row in reader:
                if (row['Mark'] == name):
                    d = {'Mark' : name}
                    for par in parameters:
                        if par[1] == 'int':
                            d[par[0]] = int(row[par[0]].replace(' ', ''))
                        else:
                            d[par[0]] = str(row[par[0]])
                    data.append(d)

    return data

# %%
data2 = pd.DataFrame(get_data_about_smb('DATA.csv', ['Polo'], ['Run', 'int'], ['Year', 'int'], ['Cost', 'int'], ['Color', 'str']))

# %%
print(data2)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
cur, cnt = 0, 0
for row in data2:
    if (row['Year'] == '2009'):
        cur += row['Cost']
        cnt += 1

a = cur/cnt
print(a*0.8, a*1.2)
# Out:
# Mark
# Run
# Year
# Cost
# Color

# %%
sns.set()
cmap = sns.cubehelix_palette(rot=-.5, as_cmap=True)
ax = sns.scatterplot(x="Run", y="Cost",
                    hue = 'Color', size="Year",
                    palette='Set2', sizes=(5, 150),
                    data=data2)

# %%
sns.set()
cmap = sns.cubehelix_palette(rot=-.5, as_cmap=True)
ax = sns.scatterplot(x="Color", y="Cost",
                    hue = 'Color', size="Year",
                    palette='Set2', sizes=(5, 150),
                    data=data2)

# %%
d = {}
from pprint import pprint
for x in range(len(data2.index)):
    if data2['Color'].iloc[x] in d:
        d[data2['Color'].iloc[x]][0] += data2['Cost'].iloc[x]
        d[data2['Color'].iloc[x]][1] += 1
    else:
        d[data2['Color'].iloc[x]] = [data2['Cost'].iloc[x], 1]
        
for i in d.keys():
    d[i] = float(d[i][0]/d[i][1])
    
pprint(d)
# Out:
# {'Black': 20316.045454545456,
#  'Blue': 13500.0,
#  'Brown': 17431.57894736842,
#  'Grey': 18046.31818181818,
#  'Other': 17257.0,
#  'Silver': 18068.75,
#  'White': 18499.30769230769}

# %%
data3 = pd.DataFrame(get_data_about_smb('DATA.csv', ['A8'], ['Run', 'int'], ['Year', 'int'], ['Cost', 'int'], ['Color', 'str']))

# %%
print(data3)
# Out:
#     Mark     Run  Year   Cost   Color
# 0     A8  261000  2010  17999   Black
# 1     A8  250000  2005   7500   Other
# 2     A8  205000  2008  13150    Blue
# 3     A8  143000  2011  21000   Black
# 4     A8  320000  2008  15500   Black
# ..   ...     ...   ...    ...     ...
# 270   A8     240  2006  11300   Black
# 271   A8   93000  2013  27000   Black
# 272   A8  287000  2003  10200   Other
# 273   A8  222000  2008   7999   Black
# 274   A8  123456  1996   4400  Silver
#
# [275 rows x 5 columns]

# %%
sns.set()
cmap = sns.cubehelix_palette(rot=-.5, as_cmap=True)
ax = sns.scatterplot(x="Run", y="Year",
                    hue = 'Color', size="Cost",
                    palette='Set2', 
                    sizes=(15, 250),
                    data=data3)

# %%
d = {}
from pprint import pprint
for x in range(len(data2.index)):
    if data2['Color'].iloc[x] in d:
        d[data2['Color'].iloc[x]][0] += data2['Cost'].iloc[x]
        d[data2['Color'].iloc[x]][1] += 1
    else:
        d[data2['Color'].iloc[x]] = [data2['Cost'].iloc[x], 1]
        
for i in d.keys():
    d[i] = float(d[i][0]/d[i][1])
    
pprint(d)
# Out:
# {'Black': 20316.045454545456,
#  'Blue': 13500.0,
#  'Brown': 17431.57894736842,
#  'Grey': 18046.31818181818,
#  'Other': 17257.0,
#  'Silver': 18068.75,
#  'White': 18499.30769230769}

# %%
sns.set()
cmap = sns.cubehelix_palette(rot=-.5, as_cmap=True)
ax = sns.scatterplot(x="Year", y="Cost",
                    hue = 'Color', #size="Year",
                    palette='Set2',# sizes=(25, 50),
                    data=data2)

# %%
sns.set()
cmap = sns.cubehelix_palette(rot=-.9, as_cmap=True)
ax = sns.scatterplot(x="Run", y="Cost",
                    hue = 'Color', #size="Year",
                    palette='Set2',# sizes=(25, 50),
                    data=data2)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')

ax.scatter(data2["Run"], data2['Year'], data2["Cost"],  c = 'skyblue', s=60)

# %%
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Color'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-0d816855b76c> in <module>
# ...

# %%
sns.set()
cmap = sns.cubehelix_palette(rot=-.5, as_cmap=True)
ax = sns.scatterplot(x="Year", y="Run",
                    hue = 'Mark', size="Cost",
                    palette='Set2', sizes=(5, 200),
                    data=data2)
sns.jointplot(x=data2['Year'], y=data2['Run'], kind='scatter')
sns.jointplot(x=data2['Year'], y=data2['Run'], kind='scatter', s=200, color='m', edgecolor="skyblue", linewidth=2)
 
# Custom the color
sns.set(style="white", color_codes=True)
sns.jointplot(x=data2['Year'], y=data2['Run'], kind='kde', color="skyblue")
# Out:
# /home/aliana/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
def get_color(url: str) -> str:
	page = requests.get(url=url)

	soup = BeautifulSoup(page.text, 'html.parser')
	data = soup.find('div', class_='card-info')
	if data is not None:
		link = data.find_all('dl')[5]
		encoded_color = link.dd.text
		if encoded_color.find('ÑÐµÑÐ½ÑÐ¹') != -1:
			color = 'Black'
		elif encoded_color.find('ÑÐµÑÑÐ¹') != -1:
			color = 'Grey'
		elif encoded_color.find('ÐºÐ¾ÑÐ¸ÑÐ½ÐµÐ²ÑÐ¹') != -1:
			color = 'Brown'
		elif encoded_color.find('Ð·ÐµÐ»ÐµÐ½ÑÐ¹') != -1:
			color = 'Green'
		elif encoded_color.find('ÑÐ¸Ð½Ð¸Ð¹') != -1:
			color = 'Blue'
		elif encoded_color.find('Ð±ÐµÐ»ÑÐ¹') != -1:
			color = 'White'
		elif encoded_color.find('ÑÐµÑÐµÐ±ÑÐ¸ÑÑÑÐ¹') != -1:
			color = 'Silver'
		elif encoded_color.find('Ð¸Ð¾Ð»ÐµÑÐ¾Ð²ÑÐ¹') != -1:
			color = 'Violet'
		else:
			color = 'Other'
		return color

# %%
data2 = pd.DataFrame(get_data_about_smb('DATA.csv', ['A6'], ['Run', 'int'], ['Year', 'int'], ['Cost', 'int'], ['Color', 'str']))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3f17e54f94af> in <module>
# ----> 1 data2 = pd.DataFrame(get_data_about_smb('DATA.csv', ['A6'], ['Run', 'int'], ['Year', 'int'], ['Cost', 'int'], ['Color', 'str']))
#
# NameError: name 'pd' is not defined
